# %% [markdown]
# # This is the dev workbook for music detection

# %% [markdown]
# ## RUN ONLY ONCE

# %%
# !pip install -r ../requirements.txt -v

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Imports

# %%
import torch
from torch.utils.data import Dataset
import torchaudio
from pathlib import Path
from torch.utils.data import DataLoader
import os
import time

# %% [markdown]
# ### AudioDataset class

# %%
class AudioDataset(Dataset):
    def __init__(self, folder_path, target_sr=22050):
        self.folder_path = folder_path
        self.target_sr = target_sr
        self.file_paths = self.get_all_filepaths()

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        init_time = time.time()
        print("loading file n°", idx)
        file_path = self.file_paths[idx]
        wav, sr = torchaudio.load(file_path)  # wav shape: (channels, time)
        wav = torch.mean(wav, dim=0)  # mono
        if sr != self.target_sr:
            wav = torchaudio.transforms.Resample(orig_freq=sr, new_freq=self.target_sr)(wav)
            sr = self.target_sr
        print(f"file loaded at sr={sr} Hz in", time.time() - init_time, "seconds")
        return wav, sr, os.path.basename(file_path)

    def get_all_filepaths(self):
        folder = Path(self.folder_path)
        file_paths = [str(p) for p in folder.rglob("*")]
        return file_paths

    def get_time_length(self, wav):
        return len(wav[0]) / self.target_sr

# %% [markdown]
# ### test dataset

# %%
dataset = AudioDataset(folder_path = "../../../Music/full_test")

mus1 = dataset[0]
mus2 = dataset[1]
print(mus2[0], len(mus2[0]))
print(mus2[1])
print(mus2[2])
print(mus1[0], len(mus1[0]))
print(mus1[1])
print(mus1[2])
# Out:
# loading file n° 0
# file loaded at sr=22050 Hz in 0.35961246490478516 seconds
# loading file n° 1
# file loaded at sr=22050 Hz in 0.5574502944946289 seconds
# tensor([ 5.4581e-14,  2.0858e-14, -8.9946e-14,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00]) 7093440
# 22050
# 20050904_56110_kson_kda_14.mp3
# tensor([-2.1066e-13, -3.4545e-13,  3.6385e-13,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00]) 4858560
# 22050
# 20040905_56110_kson_kme_04.mp3

# %% [markdown]
# ## Augmenter

# %%
import numpy as np
import librosa
import torch
import random
import torchaudio
from dataset import AudioDataset
from utils import save_wav

# %%
def normalize(wav):
    # Normalize to [-1, 1]
    max_val = wav.abs().max()
    if max_val > 0:
        wav = wav / max_val
    else:
        raise Exception("Audio is empty ...")
    return wav

class RandomClip:
    def __init__(self, sample_rate, clip_length):
        self.clip_length = sample_rate * clip_length
        self.sr = sample_rate
        self.vad = torchaudio.transforms.Vad(
            sample_rate=sample_rate, trigger_level=7.0)

    def __call__(self, audio_data):
        audio_length = audio_data.shape[0]
        print(audio_length)
        print(len(audio_data))
        print(audio_data)
        print(len(audio_data))
        if audio_length > self.clip_length:
            offset = random.randint(0, audio_length-self.clip_length)
            print(f"Audio cut between {offset/self.sr}s and, {(offset+self.clip_length)/self.sr}s")
            audio_data = audio_data[offset:(offset+self.clip_length)]
        else :
            raise Exception("Audio shorter than clip ...")
        return audio_data # remove silences at the beggining/end  self.vad()

def augment_audio(wav, sr, test = False): # TO DO implement noise adding
    if test:
        save_wav(path="tmp/test_augmenter/raw.wav", wav=wav, sr=sr)

    arr = wav.numpy().squeeze()
    n_steps=random.choice([-2, -1, 0, 1, 2])
    print(f"pitch schift of {n_steps} steps")
    arr = librosa.effects.pitch_shift(y=arr, sr=sr, n_steps=n_steps)
    if test:
        save_wav(path="tmp/test_augmenter/pitch.wav", wav=torch.tensor(arr).unsqueeze(0), sr=sr)


    rate = random.uniform(0.9, 1.1)
    print(f"time stretch rate of {rate}")
    arr = librosa.effects.time_stretch(y=arr, rate=rate)
    wav = torch.tensor(arr) #.unsqueeze(0)
    if test:
        save_wav(path="tmp/test_augmenter/stretch.wav", wav=wav, sr=sr)

    clip_transform = RandomClip(sr, clip_length = 7)
    len(wav)
    clipped_audio = clip_transform(wav)
    if test:
        save_wav(path="tmp/test_augmenter/clipped.wav", wav=clipped_audio, sr=sr)

    return clipped_audio.unsqueeze(0)

# %%
dataset = AudioDataset(folder_path = "../../../Music/full_test")
test_audio = dataset[0]
print("label",test_audio[2])
wav = augment_audio(wav=test_audio[0], sr=test_audio[1], test = True)
len(wav)
# Out:
# loading file n° 0
# file loaded at sr=22050 Hz in 0.3621690273284912 seconds
# label 20040905_56110_kson_kme_04.mp3
# Successfully saved tmp/test_augmenter/raw.wav with shape (4858560,) at 22050Hz
# pitch schift of -2 steps
# Successfully saved tmp/test_augmenter/pitch.wav with shape (4858560,) at 22050Hz
# time stretch rate of 1.0391863370571826
# Successfully saved tmp/test_augmenter/stretch.wav with shape (4675350,) at 22050Hz
# 4675350
# 4675350
# tensor([ 2.1534e-07, -5.3995e-08, -7.9182e-07,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00])
# 4675350
# Audio cut between 198.1906575963719s and, 205.1906575963719s
# Successfully saved tmp/test_augmenter/clipped.wav with shape (154350,) at 22050Hz
# 1

# %% [markdown]
# ## Model and training

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class MusicEncoder(nn.Module):
    def __init__(self, in_channels=1, out_dim=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
        )
        # works for any spectrogram shape
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(128, out_dim)

    def forward(self, x):
        x = self.conv(x)                # (B, 128, H’, W’)
        x = self.pool(x)                # (B, 128, 1, 1)
        x = x.view(x.size(0), -1)       # (B, 128)
        x = self.fc(x)                  # (B, out_dim)
        return F.normalize(x, dim=-1)   # unit vector embeddings

# %%
def contrastive_loss(z1, z2, same_label: bool, margin=1.0):
    dist = F.pairwise_distance(z1, z2)
    if same_label:
        return torch.mean(dist ** 2)  # positive → bring closer
    else:
        return torch.mean(F.relu(margin - dist) ** 2)  # negative → push apart

# %%
def get_mel_spec(wav, sr):
    spec = T.MelSpectrogram(sr, n_mels=64)(wav)
    return T.AmplitudeToDB()(spec)

# %%
encoder = MusicEncoder().cuda()  # Instantiate the audio encoder and move it to the GPU
opt = torch.optim.Adam(encoder.parameters(), 1e-3)  # Adam optimizer for training the encoder
database = {}  # Dictionary to store embeddings for each audio clip

# %%
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu129

# %%
len(dataset)
# Out:
# 6

# %%
def complete_batch_index_generator(batch_size, dataset):
    batches = []
    total_len = len(dataset)
    total_list = list(np.arange(total_len))
    while total_len > 0 :
        print("new batch")
        batch = []
        cpt = 0
        start_len = total_len
        while cpt < min(batch_size, start_len):
            index = np.random.randint(total_len)
            number = total_list.pop(index)
            batch.append(int(number))
            print(number, "added to batch")
            total_len -= 1
            cpt += 1
        batches.append(batch)
    return batches

print(complete_batch_index_generator(batch_size=1, dataset=dataset))
print(complete_batch_index_generator(batch_size=2, dataset=dataset))
# Out:
# new batch
# 0 added to batch
# new batch
# 2 added to batch
# new batch
# 1 added to batch
# new batch
# 3 added to batch
# new batch
# 4 added to batch
# new batch
# 5 added to batch
# [[0], [2], [1], [3], [4], [5]]
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# [[1, 3], [0, 4], [5, 2]]

# %%
def multiple_batch_index_generator(batch_size, loop_nb, dataset):
    batch_loop = []
    for i in range(loop_nb):
        batches = complete_batch_index_generator(batch_size, dataset)
        batch_loop += batches
    return batch_loop

batches = multiple_batch_index_generator(batch_size=2, loop_nb=5, dataset=dataset)
print(batches)
# Out:
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# [[4, 0], [1, 5], [2, 3], [1, 4], [2, 5], [0, 3], [3, 2], [4, 5], [0, 1], [0, 1], [4, 2], [3, 5], [0, 4], [1, 3], [2, 5]]

# %%
def counter_sample(audio_index, dataset):
    total_len = len(dataset)
    total_list = list(np.arange(total_len))
    same = np.random.randint(2)
    if not same:
        print("Counter example")
        total_list.pop(audio_index)
        audio2_index = np.random.randint(total_len-1)
        audio2_index = total_list[audio2_index]
    else :
        print("Same audio")
        audio2_index = audio_index
    return int(audio2_index), same

print(counter_sample(0, dataset))
# Out:
# Counter example
# (2, 0)

# %%
# all_batch = multiple_batch_index_generator(batch_size=2, loop_nb=5, dataset=dataset)
# encoder.train()

# for batch_index, batch in enumerate(all_batch): 
#     all_embeddings = []
#     all_labels = [] #collate to fit largest size
#     # Generate p augmentations for each sample
#     for i in tqdm(range(p)):
#         augmented_batch = [augment_audio(w, sr) for w in wav_batch]   # list of len n
#         mel_batch = [get_mel_spec(w, sr) for w in augmented_batch]    # list of len n
#         mel_batch = torch.stack(mel_batch).cuda()  # shape: (n, mel_bins, time_frames)
#         z_batch = encoder(mel_batch)               # shape: (n, embedding_dim)

#         all_embeddings.append(z_batch)
#         all_labels.append(torch.arange(len(wav_batch)))  # labels: 0..n-1
#         print(all_labels)

#     # Concatenate all p augmentations along the batch dimension
#     all_embeddings = torch.cat(all_embeddings, dim=0)  # shape: (n*p, embedding_dim)
#     all_labels = torch.cat(all_labels, dim=0).cuda()    # shape: (n*p,)

#     # Compute contrastive loss (e.g., NT-Xent)
#     loss = contrastive_loss(all_embeddings, all_labels)

#     # Backprop
#     opt.zero_grad()
#     loss.backward()
#     opt.step()

# print(f"Batch {batch_index}: Loss = {loss.item():.4f}")

# %%
import torchaudio.transforms as T
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device", device)
encoder = encoder.to(device)

all_batch = multiple_batch_index_generator(batch_size=2, loop_nb=500, dataset=dataset)
encoder.train()

for batch_index, batch in enumerate(all_batch): 
    all_embeddings = []
    all_labels = []
    # Generate p augmentations for each sample
    for audio_index in batch:
        wav, sr, label = dataset[audio_index]
        counter_audio_index, is_same = counter_sample(audio_index, dataset)
        counter_wav, counter_sr, counter_label = dataset[counter_audio_index]
        augmented_counter_wav = augment_audio(wav=counter_wav, sr=counter_sr)
        mel_spec = get_mel_spec(wav, sr).unsqueeze(0).unsqueeze(0).to(device) #to add the channel dimension for the model conv2D
        counter_mel_spec = get_mel_spec(augmented_counter_wav, counter_sr).unsqueeze(0).to(device)
        z = encoder(mel_spec)
        counter_z = encoder(counter_mel_spec)

        # Compute contrastive loss (e.g., NT-Xent)
        print("is_same =",is_same)
        loss = contrastive_loss(z, counter_z, is_same)
        print("z", z.cpu().detach().numpy()[0][:4], "\ncounter_z", counter_z.cpu().detach().numpy()[0][:4])
        print(f"Batch {batch_index}: Loss = {loss:.10f}, same={is_same}")

    # Backprop
    opt.zero_grad()
    loss.backward()
    opt.step()
# Out:
# device cuda
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 1 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 2 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 5 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 0 added to batch
# new batch
# 3 added to batch
# 1 added to batch
# new batch
# 5 added to batch
# 0 added to batch
# new batch
# 4 added to batch
# 2 added to batch
# new batch
# 4 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# 2 added to batch
# new batch
# 3 added to batch
# 4 added to batch
# new batch
# 0 added to batch
# 5 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 5 added to batch
# 4 added to batch
# new batch
# 2 added to batch
# 3 added to batch
# new batch
# 0 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 4 added to batch
# 3 added to batch
# new batch
# 1 added to batch
# 0 added to batch
# new batch
# 2 added to batch
# 5 added to batch
# new batch
# 0 added to batch
# 3 added to batch
# new batch
# 2 added to batch
# 4 added to batch
# new batch
# 5 added to batch
# 1 added to batch
# new batch
# 2 added to batch
# 0 added to batch
# new batch
# 1 added to batch
# ...
# 3666977
# Audio cut between 122.03451247165533s and, 129.03451247165532s
# is_same = 0
# z [ 0.0480229   0.05237712  0.00484751 -0.0291594 ]
# counter_z [ 0.07595325  0.00566413  0.02928814 -0.06410571]
# Batch 260: Loss = 0.2702597678, same=0
# loading file n° 4
# file loaded at sr=22050 Hz in 1.5808513164520264 seconds
# Same audio
# loading file n° 4
# file loaded at sr=22050 Hz in 1.5454990863800049 seconds
# pitch schift of 0 steps
# time stretch rate of 1.059459599994181
# 3263671
# 3263671
# tensor([ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -1.4983e-05,
#          2.0512e-04,  2.2514e-04])
# 3263671
# Audio cut between 91.57074829931973s and, 98.57074829931973s
# is_same = 1
# z [ 0.0185254   0.05469225 -0.01323992  0.00682537]
# counter_z [ 0.06770822 -0.00612024  0.02756003 -0.04264785]
# Batch 261: Loss = 0.3422345221, same=1
# loading file n° 2
# file loaded at sr=22050 Hz in 1.0384414196014404 seconds
# Counter example
# loading file n° 5
# file loaded at sr=22050 Hz in 1.5360286235809326 seconds
# pitch schift of 0 steps
# time stretch rate of 1.0466618190664398
# 5654548
# 5654548
# tensor([-5.1673e-09,  7.4784e-09,  5.1941e-09,  ...,  1.8562e-05,
#          1.5583e-05,  2.0116e-05])
# 5654548
# Audio cut between 185.80326530612246s and, 192.80326530612246s
# is_same = 0
# z [ 0.05181926  0.05940265  0.00837895 -0.03536844]
# counter_z [ 0.05633335 -0.00984172  0.02977914 -0.03718899]
# Batch 261: Loss = 0.2867382169, same=0
# loading file n° 5
# file loaded at sr=22050 Hz in 1.6767675876617432 seconds
# Same audio
# loading file n° 5
# file loaded at sr=22050 Hz in 1.4569475650787354 seconds
# pitch schift of 2 steps
# time stretch rate of 1.098993030834586
# 5385293
# 5385293
# tensor([-6.3205e-07, -9.8610e-07, -2.3067e-07,  ...,  3.6741e-06,
#          6.9716e-06,  4.6691e-06])
# 5385293
# Audio cut between 109.1718820861678s and, 116.1718820861678s
# is_same = 1
# z [ 0.03468517 -0.01514555  0.01935457 -0.01626607]
# counter_z [ 0.05746654 -0.02935072  0.03323613 -0.04019357]
# Batch 262: Loss = 0.0448071957, same=1
# loading file n° 1
# file loaded at sr=22050 Hz in 1.8238940238952637 seconds
# Counter example
# loading file n° 3
# file loaded at sr=22050 Hz in 1.0414063930511475 seconds
# pitch schift of 0 steps
# time stretch rate of 1.069505005712315
# 3734423
# 3734423
# tensor([ 7.5927e-05,  7.9664e-05,  7.7218e-05,  ..., -9.5106e-04,
#         -8.3810e-04, -8.9492e-04])
# 3734423
# Audio cut between 9.822947845804988s and, 16.82294784580499s
# is_same = 0
# z [ 3.8483541e-02  5.7288453e-02  7.2056609e-05 -2.1504553e-02]
# counter_z [ 0.06242723 -0.00952149  0.02891777 -0.04492734]
# Batch 262: Loss = 0.1727561057, same=0
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9732892513275146 seconds
# Same audio
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9813196659088135 seconds
# pitch schift of 1 steps
# time stretch rate of 1.0817037317393658
# 3692309
# 3692309
# tensor([ 6.7714e-05,  2.7013e-05, -2.4457e-05,  ..., -1.6987e-03,
#         -1.1969e-03, -1.5024e-03])
# 3692309
# Audio cut between 5.346893424036281s and, 12.346893424036281s
# is_same = 1
# z [ 0.03075069  0.04976551 -0.00556431 -0.00808133]
# counter_z [ 0.06651114  0.03580853  0.00968789 -0.03941455]
# Batch 263: Loss = 0.0690968707, same=1
# loading file n° 0
# file loaded at sr=22050 Hz in 1.2788467407226562 seconds
# Same audio
# loading file n° 0
# file loaded at sr=22050 Hz in 1.2287383079528809 seconds
# pitch schift of 1 steps
# time stretch rate of 1.068238485160022
# 4548198
# 4548198
# tensor([-2.5327e-07, -7.6676e-08, -1.8144e-07,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00])
# 4548198
# Audio cut between 5.43609977324263s and, 12.436099773242631s
# is_same = 1
# z [ 0.0230854   0.06801445 -0.01543934 -0.00309864]
# counter_z [ 0.05911804  0.01192489  0.01874374 -0.05493857]
# Batch 263: Loss = 0.3829223514, same=1
# loading file n° 4
# file loaded at sr=22050 Hz in 0.8621973991394043 seconds
# Counter example
# loading file n° 2
# file loaded at sr=22050 Hz in 0.9638161659240723 seconds
# pitch schift of 2 steps
# time stretch rate of 1.0341811339488238
# 3649218
# 3649218
# tensor([-1.0115e-05, -1.3311e-05,  1.7489e-05,  ...,  2.5984e-05,
#          4.0013e-04,  2.7027e-04])
# 3649218
# Audio cut between 53.937278911564626s and, 60.937278911564626s
# is_same = 0
# z [-0.00035979  0.05951142 -0.02213742  0.02556205]
# counter_z [ 0.06945982  0.00048709  0.03602331 -0.05345379]
# Batch 264: Loss = 0.0599927939, same=0
# loading file n° 0
# file loaded at sr=22050 Hz in 1.504669189453125 seconds
# Same audio
# loading file n° 0
# file loaded at sr=22050 Hz in 1.2193291187286377 seconds
# pitch schift of 0 steps
# time stretch rate of 0.9334970051582383
# 5204687
# 5204687
# tensor([-1.2722e-08, -1.5896e-08, -4.6835e-08,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00])
# 5204687
# Audio cut between 211.77179138321995s and, 218.77179138321995s
# is_same = 1
# z [ 0.01852759  0.07017023 -0.01667549  0.00072619]
# counter_z [ 0.06024177  0.0351099   0.01324818 -0.03384148]
# Batch 264: Loss = 0.2038165331, same=1
# loading file n° 1
# file loaded at sr=22050 Hz in 1.7603590488433838 seconds
# Same audio
# loading file n° 1
# file loaded at sr=22050 Hz in 1.8682975769042969 seconds
# pitch schift of 0 steps
# time stretch rate of 1.0724863273264644
# 6614014
# 6614014
# tensor([ 1.4938e-06,  6.1125e-07,  6.9839e-07,  ..., -2.3972e-04,
#          4.9049e-06,  2.2452e-04])
# 6614014
# Audio cut between 16.420045351473924s and, 23.420045351473924s
# is_same = 1
# z [ 0.02258823  0.06557024 -0.00744402 -0.00980096]
# counter_z [ 0.05586791 -0.00432946  0.02902376 -0.04437095]
# Batch 265: Loss = 0.4521830678, same=1
# loading file n° 3
# file loaded at sr=22050 Hz in 1.1570422649383545 seconds
# Counter example
# loading file n° 4
# file loaded at sr=22050 Hz in 1.0558457374572754 seconds
# pitch schift of -1 steps
# time stretch rate of 1.0692152336069587
# 3233893
# 3233893
# tensor([ 0.0000,  0.0000,  0.0000,  ..., -0.0008, -0.0004, -0.0001])
# 3233893
# Audio cut between 54.2946485260771s and, 61.2946485260771s
# is_same = 0
# z [ 0.02161761  0.05240323 -0.01012531  0.00053987]
# counter_z [ 0.05267251 -0.02249176  0.03414135 -0.03912438]
# Batch 265: Loss = 0.1218689308, same=0
# loading file n° 2
# file loaded at sr=22050 Hz in 0.9240946769714355 seconds
# Counter example
# loading file n° 0
# file loaded at sr=22050 Hz in 1.2344567775726318 seconds
# pitch schift of -2 steps
# time stretch rate of 0.9270842382395968
# 5240689
# 5240689
# tensor([ 1.5335e-07, -1.6036e-07, -8.3785e-07,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00])
# 5240689
# Audio cut between 124.96408163265306s and, 131.96408163265306s
# is_same = 0
# z [ 0.02786725  0.07433151 -0.00500373 -0.01790776]
# counter_z [ 0.05817209 -0.03090882  0.03597635 -0.05317745]
# Batch 266: Loss = 0.0236047097, same=0
# loading file n° 5
# file loaded at sr=22050 Hz in 1.5092980861663818 seconds
# Same audio
# loading file n° 5
# file loaded at sr=22050 Hz in 1.4776217937469482 seconds
# pitch schift of -1 steps
# time stretch rate of 1.0867150792280171
# 5446138
# 5446138
# tensor([-2.5908e-07,  1.5105e-07,  6.6929e-08,  ...,  4.6106e-05,
#          4.2489e-05,  4.5094e-05])
# 5446138
# Audio cut between 157.7231746031746s and, 164.7231746031746s
# is_same = 1
# z [ 0.01609612 -0.02503416  0.01740831 -0.00082212]
# counter_z [ 0.04368784 -0.03464147  0.03379227 -0.04014669]
# Batch 266: Loss = 0.0512493923, same=1
# loading file n° 0
# file loaded at sr=22050 Hz in 1.2265288829803467 seconds
# Counter example
# loading file n° 3
# file loaded at sr=22050 Hz in 1.2685697078704834 seconds
# pitch schift of -1 steps
# time stretch rate of 1.0790140148135101
# 3701513
# 3701513
# tensor([ 8.7637e-05,  9.3368e-05,  5.7576e-05,  ..., -2.3709e-03,
#         -1.7844e-03, -6.7438e-04])
# 3701513
# Audio cut between 148.22371882086168s and, 155.22371882086168s
# is_same = 0
# z [ 0.00576035  0.0777208  -0.01850644  0.00942603]
# counter_z [ 0.04021114  0.00151485  0.01967073 -0.03150739]
# Batch 267: Loss = 0.0749244764, same=0
# loading file n° 4
# file loaded at sr=22050 Hz in 0.9162566661834717 seconds
# Counter example
# loading file n° 3
# file loaded at sr=22050 Hz in 1.0385265350341797 seconds
# pitch schift of 0 steps
# time stretch rate of 1.0605687556194499
# 3765889
# 3765889
# tensor([6.6178e-05, 6.9426e-05, 6.7269e-05,  ..., 2.3519e-03, 2.4188e-03,
#         2.9524e-03])
# 3765889
# Audio cut between 8.0659410430839s and, 15.0659410430839s
# is_same = 0
# z [-0.01463678  0.06540635 -0.0258464   0.03873679]
# counter_z [ 0.03242539  0.03482918  0.00296368 -0.0103126 ]
# Batch 267: Loss = 0.2903590798, same=0
# loading file n° 2
# file loaded at sr=22050 Hz in 0.9181103706359863 seconds
# Counter example
# loading file n° 5
# file loaded at sr=22050 Hz in 1.5330586433410645 seconds
# pitch schift of 1 steps
# time stretch rate of 1.0685550160155255
# 5538695
# 5538695
# tensor([-5.2016e-07, -1.1023e-07, -1.0862e-07,  ...,  4.8317e-05,
#          4.4626e-05,  4.2163e-05])
# 5538695
# Audio cut between 180.75814058956917s and, 187.75814058956917s
# is_same = 0
# z [ 0.02048663  0.07811029 -0.00921567 -0.01369159]
# counter_z [ 0.04206818 -0.02119113  0.02820405 -0.02082168]
# Batch 268: Loss = 0.0682553425, same=0
# loading file n° 1
# file loaded at sr=22050 Hz in 2.0232088565826416 seconds
# Same audio
# loading file n° 1
# file loaded at sr=22050 Hz in 1.8339059352874756 seconds
# pitch schift of 1 steps
# time stretch rate of 1.0234380336374493
# 6930991
# 6930991
# tensor([ 3.1747e-07, -1.5307e-07, -1.8230e-07,  ..., -5.1484e-04,
#         -5.9291e-04, -6.5400e-04])
# 6930991
# Audio cut between 100.77179138321995s and, 107.77179138321995s
# is_same = 1
# z [ 0.00951159  0.07250697 -0.01360383 -0.00150761]
# counter_z [ 0.05014102  0.00269707  0.02814595 -0.04176291]
# Batch 268: Loss = 0.4573355615, same=1
# loading file n° 3
# file loaded at sr=22050 Hz in 1.0078027248382568 seconds
# Same audio
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9982709884643555 seconds
# pitch schift of 0 steps
# time stretch rate of 1.0136178190493095
# 3940325
# 3940325
# tensor([1.4964e-05, 1.5637e-05, 1.5003e-05,  ..., 2.5343e-03, 1.6545e-03,
#         1.1944e-03])
# 3940325
# Audio cut between 155.68471655328798s and, 162.68471655328798s
# is_same = 1
# z [ 0.00771447  0.05587469 -0.01576168  0.01188833]
# counter_z [ 0.02766167  0.03111371 -0.00617344 -0.01764093]
# Batch 269: Loss = 0.0628101826, same=1
# loading file n° 5
# file loaded at sr=22050 Hz in 1.4815738201141357 seconds
# Same audio
# loading file n° 5
# file loaded at sr=22050 Hz in 1.4831030368804932 seconds
# pitch schift of 2 steps
# time stretch rate of 1.0077872567840955
# 5872668
# 5872668
# tensor([-4.9507e-08, -7.7567e-08, -1.8006e-08,  ...,  9.9328e-06,
#          8.2931e-06,  9.3142e-06])
# 5872668
# Audio cut between 212.54244897959182s and, 219.54244897959182s
# is_same = 1
# z [ 0.01015194 -0.0317946   0.01899843  0.00192911]
# counter_z [ 0.04731858 -0.03942131  0.03410494 -0.03635832]
# Batch 269: Loss = 0.0626989976, same=1
# loading file n° 2
# file loaded at sr=22050 Hz in 0.9510979652404785 seconds
# Counter example
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9847238063812256 seconds
# pitch schift of -1 steps
# time stretch rate of 0.958661864626603
# 4166207
# 4166207
# tensor([ 5.9636e-05,  6.7863e-05,  6.1764e-05,  ..., -9.1427e-04,
#         -8.5406e-04, -7.8806e-04])
# 4166207
# Audio cut between 141.1332879818594s and, 148.1332879818594s
# is_same = 0
# z [ 0.01773955  0.07944594 -0.01069377 -0.01411365]
# counter_z [ 0.03350296  0.00353187  0.01098812 -0.026151  ]
# Batch 270: Loss = 0.1555714309, same=0
# loading file n° 5
# file loaded at sr=22050 Hz in 1.526336669921875 seconds
# Same audio
# loading file n° 5
# file loaded at sr=22050 Hz in 1.5074472427368164 seconds
# pitch schift of -2 steps
# time stretch rate of 1.0717669152619025
# 5522096
# 5522096
# tensor([ 2.5397e-08,  4.3107e-07,  7.0829e-07,  ..., -1.9355e-05,
#         -1.8217e-05, -1.3033e-05])
# 5522096
# Audio cut between 82.59655328798186s and, 89.59655328798186s
# is_same = 1
# z [ 0.01143109 -0.03278488  0.02049834 -0.00013615]
# counter_z [ 0.03596814 -0.03227324  0.02906705 -0.04668946]
# Batch 270: Loss = 0.0902536884, same=1
# loading file n° 0
# file loaded at sr=22050 Hz in 1.239877462387085 seconds
# Counter example
# loading file n° 2
# file loaded at sr=22050 Hz in 1.1314868927001953 seconds
# pitch schift of -2 steps
# time stretch rate of 1.0476891357170224
# 3602168
# 3602168
# tensor([-5.5723e-05, -1.3928e-04, -8.6535e-05,  ..., -4.3056e-04,
#         -7.0695e-04, -5.4010e-04])
# 3602168
# Audio cut between 98.98607709750567s and, 105.98607709750567s
# is_same = 0
# z [ 0.0021362   0.0802881  -0.0174422   0.00922557]
# counter_z [ 0.05588572 -0.01068228  0.03192934 -0.0616677 ]
# Batch 271: Loss = 0.0088915406, same=0
# loading file n° 4
# file loaded at sr=22050 Hz in 0.8903696537017822 seconds
# Counter example
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9714524745941162 seconds
# pitch schift of 0 steps
# time stretch rate of 1.062929173986627
# 3757526
# 3757526
# tensor([ 6.8753e-05,  7.2131e-05,  6.9897e-05,  ..., -7.6642e-05,
#         -1.3157e-04, -1.8061e-04])
# 3757526
# Audio cut between 41.38090702947846s and, 48.38090702947846s
# is_same = 0
# z [-0.01888962  0.06616819 -0.02378412  0.04118901]
# counter_z [ 0.02289136  0.0475945  -0.00945637 -0.01059743]
# Batch 271: Loss = 0.3732974827, same=0
# loading file n° 1
# file loaded at sr=22050 Hz in 2.0025742053985596 seconds
# Same audio
# loading file n° 1
# file loaded at sr=22050 Hz in 1.855618953704834 seconds
# pitch schift of 2 steps
# time stretch rate of 1.053767002926569
# 6731507
# 6731507
# tensor([-3.2844e-08, -8.6444e-07, -1.1452e-07,  ...,  1.6287e-04,
#          2.0920e-04,  2.1826e-04])
# 6731507
# Audio cut between 245.29469387755103s and, 252.29469387755103s
# is_same = 1
# z [ 0.01166221  0.06949062 -0.01146337 -0.00902613]
# counter_z [ 0.04212493 -0.00186669  0.03470019 -0.05028493]
# Batch 272: Loss = 0.4634566903, same=1
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9623727798461914 seconds
# Same audio
# loading file n° 3
# file loaded at sr=22050 Hz in 0.9846310615539551 seconds
# pitch schift of 1 steps
# time stretch rate of 1.0075531637544097
# 3964043
# 3964043
# tensor([ 5.8959e-06,  2.4560e-06, -1.3884e-06,  ...,  1.7841e-03,
#          1.3234e-03,  1.0811e-03])
# 3964043
# Audio cut between 61.33369614512472s and, 68.33369614512472s
# is_same = 1
# z [ 0.01248902  0.04949556 -0.00945055  0.0049739 ]
# counter_z [ 0.05273487 -0.01247934  0.02820683 -0.03539532]
# Batch 272: Loss = 0.3247330487, same=1
# loading file n° 0
# file loaded at sr=22050 Hz in 1.239837408065796 seconds
# Same audio
# loading file n° 0
# file loaded at sr=22050 Hz in 1.4228260517120361 seconds
# pitch schift of -1 steps
# time stretch rate of 1.0860873291764521
# 4473452
# 4473452
# tensor([ 2.2423e-08,  1.8703e-07, -1.0835e-07,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00])
# 4473452
# Audio cut between 130.9229931972789s and, 137.9229931972789s
# is_same = 1
# z [ 0.00818556  0.07803877 -0.01606463  0.00305771]
# counter_z [ 0.05109701 -0.00672744  0.03162459 -0.05303202]
# Batch 273: Loss = 0.6419707537, same=1
# loading file n° 5
# file loaded at sr=22050 Hz in 1.618837594985962 seconds
# Same audio
# loading file n° 5
# file loaded at sr=22050 Hz in 1.4940335750579834 seconds
# pitch schift of -2 steps
# time stretch rate of 1.0946541526859679
# 5406639
# 5406639
# tensor([ 3.4731e-08,  5.6817e-07,  9.3022e-07,  ..., -4.8441e-05,
#         -4.4900e-05, -3.8649e-05])
# 5406639
# Audio cut between 115.19732426303855s and, 122.19732426303855s
# is_same = 1
# z [ 0.02158991 -0.03783077  0.0258683  -0.01276546]
# counter_z [ 0.03303833 -0.04194549  0.036244   -0.04291954]
# Batch 273: Loss = 0.0422358252, same=1
# loading file n° 4
# file loaded at sr=22050 Hz in 0.9286766052246094 seconds
# Counter example
# loading file n° 0
# file loaded at sr=22050 Hz in 1.2254292964935303 seconds
# pitch schift of -1 steps
# time stretch rate of 1.0764447526321133
# 4513525
# 4513525
# tensor([ 2.8124e-08,  1.5442e-07, -1.4433e-07,  ...,  0.0000e+00,
#          0.0000e+00,  0.0000e+00])
# 4513525
# Audio cut between 44.87047619047619s and, 51.87047619047619s
# is_same = 0
# z [-0.00871883  0.06024236 -0.01901254  0.03237627]
# counter_z [ 0.05965969 -0.00351386  0.02862179 -0.04886504]
# Batch 274: Loss = 0.1035186052, same=0
# loading file n° 2
# file loaded at sr=22050 Hz in 0.8456594944000244 seconds
# Counter example
# loading file n° 4
# file loaded at sr=22050 Hz in 1.058351755142212 seconds
# pitch schift of -2 steps

# %%
import faiss

# %%
# --- Build Embedding Database ---
encoder.eval()  # Set encoder to evaluation mode
embs = []  # List to store embeddings
labels = []  # List to store corresponding labels


# For each clip, compute and store its embedding
for wav, sr, label in dataset:
    m = get_mel_spec(wav, sr).unsqueeze(0).unsqueeze(0).cuda()  # Mel spectrogram, batch dimension, move to GPU
    with torch.no_grad():
        em = encoder(m).cpu().numpy()[0]  # Get embedding, move to CPU, convert to numpy
    database[label] = em  # Store in database dictionary
    embs.append(em)  # Add to embedding list
    labels.append(label)  

dim = embs[0].shape[0]  # Dimensionality of embeddings
index = faiss.IndexFlatL2(dim)  # Create a FAISS index for fast nearest neighbor search (L2 distance)
index.add(np.array(embs))  # Add all embeddings to the index
# Out:
# loading file n° 0
# file loaded at sr=22050 Hz in 0.31972718238830566 seconds
# loading file n° 1
# file loaded at sr=22050 Hz in 0.30269622802734375 seconds
# loading file n° 2

# %%
import gradio as gr

# %%
# --- Gradio Demo ---
def recognize(inp):
    if inp is None:
        return "Please upload an audio file"
    
    try:
        wav2, sr2 = torchaudio.load(inp)
        if sr2 != 22050:
            wav2 = torchaudio.transforms.Resample(orig_freq=sr2, new_freq=22050)(wav2)
        wav2 = torch.mean(wav2, dim=0)
        m = get_mel_spec(wav2, sr2).unsqueeze(0).unsqueeze(0).cuda()
        with torch.no_grad():
            em2 = encoder(m).cpu().numpy()
        D, I = index.search(em2, 1)
        return f"Closest Match: {labels[I[0][0]]} (dist {D[0][0]:.3f})"
    except Exception as e:
        return f"Error processing audio: {str(e)}"

gr.Interface(
    fn=recognize,
    inputs=gr.Audio(type="filepath"),
    outputs="text",
    title="Music Recognizer Demo"
).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\mathi\repos\music_detection\.venv\Lib\site-packages\torchaudio\_backend\utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
